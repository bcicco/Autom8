# %%
import sys
from pathlib import Path

BACKEND_ROOT = Path.cwd().parents[0]  
sys.path.insert(0, str(BACKEND_ROOT))

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\benja\Desktop\Form experimentation Lets Go!\backend\notebooks

# %%
from helpers.htmlCleaner import clean_html_for_llm

file_path = 'test_html.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()
print("html length: ", len(content))

clean_html = clean_html_for_llm(content)
print("clean html length", len(clean_html))
# Out:
# html length:  64307
# I changed this
# clean html length 5791

# %%
print(clean_html)
# Out:
# <html><body><form action="/ola/app" id="A" method="post"><input name="wc_t" type="hidden" value="d8971314-4c85-423f-a7c8-42cfd6710c83"/><input name="wc_s" type="hidden" value="2"/><div id="_0a1"><div id="uid481765788571549">
# <button type="button">
# </button>
# </div>
# ...
